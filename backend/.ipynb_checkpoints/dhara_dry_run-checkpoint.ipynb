# %%
import sys, os, json
from pathlib import Path

BACKEND_DIR = Path.cwd() if (Path.cwd() / "extractor.py").exists() else Path.cwd() / "backend"
sys.path.insert(0, str(BACKEND_DIR))
os.chdir(BACKEND_DIR)
print("Using backend dir:", BACKEND_DIR)

from dotenv import load_dotenv
load_dotenv()

SKIP_LLM = False     # set False to use real Claude calls (needs ANTHROPIC_API_KEY)
RUN_DB_PUSH = True  # set True to actually write to Postgres (needs DATABASE_URL reachable)

from extractor import TableExtractor
import catalogue as cat
from metadata_llm import extract_excel_facts, generate_metadata_with_llm, parse_llm_metadata_output

print("Modules loaded OK")
# Out:
# Using backend dir: /Users/sriramrahul/Desktop/dhara-toolkit-own/dhara-poc/backend
# Modules loaded OK

# %% [markdown]
# ## Stage 0 — Load a sample dataset workbook
#
# Dhara ingests government-style statistical Excel workbooks: a `TABLE: <code>` marker row, a title/description,
# one or two-level merged column headers (e.g. `INSTITUTIONAL` spanning `MALE/FEMALE/OTHER/TOTAL`), a data body
# (often ending in an `ALL` total row), and sheets that frequently pack two sub-tables back to back — an URBAN
# block immediately followed by a RURAL block on the same sheet.
#
# This notebook loads a **real** sample workbook of that exact shape
# (`sample_data/Infant_Mother_Death_D12-D18.xlsx` — Infant & Mother Death tables D-12 through D-18, 5 sheets,
# URBAN/RURAL split per sheet) so the extraction stage below runs against actual field data rather than a
# synthetic stand-in. Swap in any similarly-shaped workbook by dropping it into `sample_data/` and updating
# `SAMPLE_XLSX_PATH`.

# %%
import openpyxl

SAMPLE_XLSX_PATH = BACKEND_DIR / "sample_data" / "Infant_Mother_Death_D12-D18.xlsx"

# SAMPLE_XLSX_PATH = BACKEND_DIR / "sample_data" / "Still Birth Table-2024.xlsx"

sample_filename = SAMPLE_XLSX_PATH.name
sample_bytes = SAMPLE_XLSX_PATH.read_bytes()

wb_preview = openpyxl.load_workbook(SAMPLE_XLSX_PATH, data_only=True)
print(f"Loaded {sample_filename} ({len(sample_bytes)} bytes)")
print("Sheets:", wb_preview.sheetnames)
# Out:
# Loaded Infant_Mother_Death_D12-D18.xlsx (253856 bytes)
# Sheets: ['D-12 & D-13', 'D-14', 'D-15', 'D-16', 'D-18']

# %% [markdown]
# ## Stage 1 — Table extraction
#
# `TableExtractor.extract_from_file` (the same code the `/api/extract` and `/api/catalogue/batch-extract`
# endpoints call):
#
# 1. Loads the workbook, builds a merge-resolved "filled grid" per sheet
# 2. Finds table blocks (via `TABLE:` markers, or blank-row fallback)
# 3. Strips title/description rows, infers header/skip rows and column names
#    (heuristically here since `SKIP_LLM=True`; the direct-LLM strategy would replace `_heuristic_structure`)
# 4. Builds row dicts, captures raw header rows / footnotes
# 5. Generates a DDI-format table ID and dedupes IDs/titles across the whole batch

# %%
extractor = TableExtractor(api_key=None, skip_llm=True)
tables = extractor.extract_from_file(sample_bytes, sample_filename)

for t in tables:
    t["source_file"] = sample_filename

print(f"Extracted {len(tables)} tables\n")
for t in tables:
    print(f"- id={t['id']}")
    print(f"    table_id    : {t['table_id']}")
    print(f"    title       : {t['title']}")
    print(f"    sheet       : {t['sheet']}")
    print(f"    columns     : {t['columns']}")
    print(f"    row_count   : {t['row_count']}")
    print(f"    sample row  : {t['rows'][0] if t['rows'] else None}")
    print()
# Out:
# [DEBUG] sheet='D-12 & D-13'  grid_rows=18  blocks=[(0, 7), (10, 17)]
# [DEBUG] sheet='D-14'  grid_rows=8  blocks=[(0, 7)]
# [DEBUG] sheet='D-15'  grid_rows=18  blocks=[(0, 7), (10, 17)]
# [DEBUG] sheet='D-16'  grid_rows=18  blocks=[(0, 7), (10, 17)]
# [DEBUG] sheet='D-18'  grid_rows=29  blocks=[(0, 13), (15, 28)]
# Extracted 9 tables
#
# - id=DDI_DEL_DES_VS_D12_URBAN_2024_V1
#     table_id    : TABLE: D-12 & D-13
#     title       : INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (URBAN)
#     sheet       : D-12 & D-13
#     columns     : ['SL. NO.', 'DISTRICT', 'INSTITUTIONAL', 'INSTITUTIONAL_1', 'INSTITUTIONAL_2', 'INSTITUTIONAL_3', 'DOMICILIARY', 'DOMICILIARY_1', 'DOMICILIARY_2', 'DOMICILIARY_3', 'ALL', 'ALL_1', 'ALL_2', 'ALL_3']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'DISTRICT': 'MCD', 'INSTITUTIONAL': 2241.0, 'INSTITUTIONAL_1': 1624.0, 'INSTITUTIONAL_2': 6.0, 'INSTITUTIONAL_3': 3871, 'DOMICILIARY': 14.0, 'DOMICILIARY_1': 20.0, 'DOMICILIARY_2': 0.0, 'DOMICILIARY_3': 34, 'ALL': 2255, 'ALL_1': 1644, 'ALL_2': 6, 'ALL_3': 3905}
#
# - id=DDI_DEL_DES_VS_D12_RURAL_2024_V1
#     table_id    : TABLE: D-12 & D-13 (2)
#     title       : INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (RURAL)
#     sheet       : D-12 & D-13
#     columns     : ['SL. NO.', 'DISTRICT', 'INSTITUTIONAL', 'INSTITUTIONAL_1', 'INSTITUTIONAL_2', 'INSTITUTIONAL_3', 'DOMICILIARY', 'DOMICILIARY_1', 'DOMICILIARY_2', 'DOMICILIARY_3', 'ALL', 'ALL_1', 'ALL_2', 'ALL_3']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'DISTRICT': 'MCD', 'INSTITUTIONAL': 296.0, 'INSTITUTIONAL_1': 185.0, 'INSTITUTIONAL_2': 0.0, 'INSTITUTIONAL_3': 481, 'DOMICILIARY': 1.0, 'DOMICILIARY_1': 1.0, 'DOMICILIARY_2': 0.0, 'DOMICILIARY_3': 2, 'ALL': 297, 'ALL_1': 186, 'ALL_2': 0, 'ALL_3': 483}
#
# - id=DDI_DEL_DES_VS_D14_2024_V1
#     table_id    : TABLE :D-14
#     title       : INFANTS DEATHS BY AGE AND SEX
#     sheet       : D-14
#     columns     : ['SL. NO.', 'AGE', 'URBAN', 'URBAN_1', 'URBAN_2', 'URBAN_3', 'RURAL', 'RURAL_1', 'RURAL_2', 'RURAL_3', 'ALL', 'ALL_1', 'ALL_2', 'ALL_3']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'AGE': '< 7 DAYS', 'URBAN': 1507.0, 'URBAN_1': 1056.0, 'URBAN_2': 7.0, 'URBAN_3': 2570, 'RURAL': 394.0, 'RURAL_1': 238.0, 'RURAL_2': 1.0, 'RURAL_3': 633, 'ALL': 1901.0, 'ALL_1': 1294.0, 'ALL_2': 8.0, 'ALL_3': 3203}
#
# - id=DDI_DEL_DES_VS_D15_URBAN_2024_V1
#     table_id    : TABLE : D-15
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (URBAN)
#     sheet       : D-15
#     columns     : ['SL. NO.', 'CAUSE', 'DESCRIPTION', 'AGE OF MOTHER', 'AGE OF MOTHER_1', 'AGE OF MOTHER_2', 'AGE OF MOTHER_3', 'AGE OF MOTHER_4', 'AGE OF MOTHER_5', 'AGE OF MOTHER_6', 'AGE OF MOTHER_7', 'ALL']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'CAUSE': 'O00-O08', 'DESCRIPTION': 'PREGNANCY, WITH ABORTIVE OUTCOME', 'AGE OF MOTHER': 0.0, 'AGE OF MOTHER_1': 0.0, 'AGE OF MOTHER_2': 2.0, 'AGE OF MOTHER_3': 2.0, 'AGE OF MOTHER_4': 1.0, 'AGE OF MOTHER_5': 1.0, 'AGE OF MOTHER_6': 1.0, 'AGE OF MOTHER_7': 0.0, 'ALL': 7}
#
# - id=DDI_DEL_DES_VS_D15_RURAL_2024_V1
#     table_id    : TABLE : D-15 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (RURAL)
#     sheet       : D-15
#     columns     : ['SL. NO.', 'CAUSE', 'DESCRIPTION', 'AGE OF MOTHER', 'AGE OF MOTHER_1', 'AGE OF MOTHER_2', 'AGE OF MOTHER_3', 'AGE OF MOTHER_4', 'AGE OF MOTHER_5', 'AGE OF MOTHER_6', 'AGE OF MOTHER_7', 'ALL']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'CAUSE': 'O00-O08', 'DESCRIPTION': 'PREGNANCY, WITH ABORTIVE OUTCOME', 'AGE OF MOTHER': 0.0, 'AGE OF MOTHER_1': 0.0, 'AGE OF MOTHER_2': 0.0, 'AGE OF MOTHER_3': 1.0, 'AGE OF MOTHER_4': 0.0, 'AGE OF MOTHER_5': 0.0, 'AGE OF MOTHER_6': 0.0, 'AGE OF MOTHER_7': 0.0, 'ALL': 1}
#
# - id=DDI_DEL_DES_VS_D16_URBAN_2024_V1
#     table_id    : TABLE : D-16
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (URBAN)
#     sheet       : D-16
#     columns     : ['SL. NO.', 'CAUSE', 'DESCRIPTION', 'AGE OF MOTHER', 'AGE OF MOTHER_1', 'AGE OF MOTHER_2', 'AGE OF MOTHER_3', 'AGE OF MOTHER_4', 'AGE OF MOTHER_5', 'AGE OF MOTHER_6', 'AGE OF MOTHER_7', 'ALL']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'CAUSE': 'O00-O08', 'DESCRIPTION': 'PREGNANCY, WITH ABORTIVE OUTCOME', 'AGE OF MOTHER': 0.0, 'AGE OF MOTHER_1': 1.0, 'AGE OF MOTHER_2': 2.0, 'AGE OF MOTHER_3': 3.0, 'AGE OF MOTHER_4': 2.0, 'AGE OF MOTHER_5': 3.0, 'AGE OF MOTHER_6': 1.0, 'AGE OF MOTHER_7': 5.0, 'ALL': 17}
#
# - id=DDI_DEL_DES_VS_D16_RURAL_2024_V1
#     table_id    : TABLE : D-16 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (RURAL)
#     sheet       : D-16
#     columns     : ['SL. NO.', 'CAUSE', 'DESCRIPTION', 'AGE OF MOTHER', 'AGE OF MOTHER_1', 'AGE OF MOTHER_2', 'AGE OF MOTHER_3', 'AGE OF MOTHER_4', 'AGE OF MOTHER_5', 'AGE OF MOTHER_6', 'AGE OF MOTHER_7', 'ALL']
#     row_count   : 4
#     sample row  : {'SL. NO.': 1.0, 'CAUSE': 'O00-O08', 'DESCRIPTION': 'PREGNANCY, WITH ABORTIVE OUTCOME', 'AGE OF MOTHER': 0.0, 'AGE OF MOTHER_1': 0.0, 'AGE OF MOTHER_2': 0.0, 'AGE OF MOTHER_3': 2.0, 'AGE OF MOTHER_4': 1.0, 'AGE OF MOTHER_5': 0.0, 'AGE OF MOTHER_6': 0.0, 'AGE OF MOTHER_7': 0.0, 'ALL': 3}
#
# - id=DDI_DEL_DES_VS_D18_URBAN_2024_V1
#     table_id    : TABLE: D-18
#     title       : PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (URBAN)
#     sheet       : D-18
#     columns     : ['SL. NO.', 'OCCUPATION', 'AGE GROUP', 'AGE GROUP_1', 'AGE GROUP_2', 'AGE GROUP_3', 'AGE GROUP_4', 'AGE GROUP_5', 'AGE GROUP_6', 'AGE GROUP_7', 'AGE GROUP_8']
#     row_count   : 10
#     sample row  : {'SL. NO.': 1.0, 'OCCUPATION': 'PROFESSIONAL / TECHNICAL RELATED WORKERS', 'AGE GROUP': 0.0, 'AGE GROUP_1': 0.0, 'AGE GROUP_2': 0.0, 'AGE GROUP_3': 2.0, 'AGE GROUP_4': 1.0, 'AGE GROUP_5': 0.0, 'AGE GROUP_6': 0.0, 'AGE GROUP_7': 0.0, 'AGE GROUP_8': 3}
#
# - id=DDI_DEL_DES_VS_D18_RURAL_2024_V1
#     table_id    : TABLE: D-18 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (RURAL)
#     sheet       : D-18
#     columns     : ['SL. NO.', 'OCCUPATION', 'AGE GROUP', 'AGE GROUP_1', 'AGE GROUP_2', 'AGE GROUP_3', 'AGE GROUP_4', 'AGE GROUP_5', 'AGE GROUP_6', 'AGE GROUP_7', 'AGE GROUP_8']
#     row_count   : 10
#     sample row  : {'SL. NO.': 1.0, 'OCCUPATION': 'PROFESSIONAL / TECHNICAL RELATED WORKERS', 'AGE GROUP': 0.0, 'AGE GROUP_1': 0.0, 'AGE GROUP_2': 0.0, 'AGE GROUP_3': 0.0, 'AGE GROUP_4': 0.0, 'AGE GROUP_5': 0.0, 'AGE GROUP_6': 0.0, 'AGE GROUP_7': 0.0, 'AGE GROUP_8': 0}

# %%
from validation import validate_table_fields_code, validate_table_fields_llm

print("Validating extracted Table ID / Table Title fields\n")
for t in tables:
    code_result = validate_table_fields_code(t["table_id"], t["title"])

    try:
        llm_result = validate_table_fields_llm(t["table_id"], t["title"])
    except Exception as e:
        llm_result = {"valid": None, "issues": [f"LLM validation skipped ({e})"]}

    print(f"- id={t['id']}")
    print(f"    table_id    : {t['table_id']}")
    print(f"    title       : {t['title']}")
    print(f"    code-based validation  : valid={code_result['valid']} issues={code_result['issues']}")
    print(f"    prompt-based validation: valid={llm_result['valid']} issues={llm_result['issues']}")
    print()
# Out:
# Validating extracted Table ID / Table Title fields
#
# - id=DDI_DEL_DES_VS_D12_URBAN_2024_V1
#     table_id    : TABLE: D-12 & D-13
#     title       : INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (URBAN)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=False issues=['The Table ID and Table Title look swapped']
#
# - id=DDI_DEL_DES_VS_D12_RURAL_2024_V1
#     table_id    : TABLE: D-12 & D-13 (2)
#     title       : INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (RURAL)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D14_2024_V1
#     table_id    : TABLE :D-14
#     title       : INFANTS DEATHS BY AGE AND SEX
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=False issues=['The Table ID and Table Title look swapped']
#
# - id=DDI_DEL_DES_VS_D15_URBAN_2024_V1
#     table_id    : TABLE : D-15
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (URBAN)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D15_RURAL_2024_V1
#     table_id    : TABLE : D-15 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (RURAL)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D16_URBAN_2024_V1
#     table_id    : TABLE : D-16
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (URBAN)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D16_RURAL_2024_V1
#     table_id    : TABLE : D-16 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (RURAL)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D18_URBAN_2024_V1
#     table_id    : TABLE: D-18
#     title       : PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (URBAN)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]
#
# - id=DDI_DEL_DES_VS_D18_RURAL_2024_V1
#     table_id    : TABLE: D-18 (2)
#     title       : PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (RURAL)
#     code-based validation  : valid=True issues=[]
#     prompt-based validation: valid=True issues=[]

# %%
# Full structure of one extracted table, for inspection (D-12/D-13, urban block)
print(json.dumps(tables[0], indent=2, default=str))
# Out:
# {
#   "id": "DDI_DEL_DES_VS_D12_URBAN_2024_V1",
#   "table_id": "TABLE: D-12 & D-13",
#   "title": "INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (URBAN)",
#   "sheet": "D-12 & D-13",
#   "filename": "Infant_Mother_Death_D12-D18.xlsx",
#   "columns": [
#     "SL. NO.",
#     "DISTRICT",
#     "INSTITUTIONAL",
#     "INSTITUTIONAL_1",
#     "INSTITUTIONAL_2",
#     "INSTITUTIONAL_3",
#     "DOMICILIARY",
#     "DOMICILIARY_1",
#     "DOMICILIARY_2",
#     "DOMICILIARY_3",
#     "ALL",
#     "ALL_1",
#     "ALL_2",
#     "ALL_3"
#   ],
#   "rows": [
#     {
#       "SL. NO.": 1.0,
#       "DISTRICT": "MCD",
#       "INSTITUTIONAL": 2241.0,
#       "INSTITUTIONAL_1": 1624.0,
#       "INSTITUTIONAL_2": 6.0,
#       "INSTITUTIONAL_3": 3871,
#       "DOMICILIARY": 14.0,
#       "DOMICILIARY_1": 20.0,
#       "DOMICILIARY_2": 0.0,
#       "DOMICILIARY_3": 34,
#       "ALL": 2255,
#       "ALL_1": 1644,
#       "ALL_2": 6,
#       "ALL_3": 3905
#     },
#     {
#       "SL. NO.": 2.0,
#       "DISTRICT": "NDMC   ",
#       "INSTITUTIONAL": 703.0,
#       "INSTITUTIONAL_1": 542.0,
#       "INSTITUTIONAL_2": 1.0,
#       "INSTITUTIONAL_3": 1246,
#       "DOMICILIARY": 0.0,
#       "DOMICILIARY_1": 0.0,
#       "DOMICILIARY_2": 0.0,
#       "DOMICILIARY_3": 0,
#       "ALL": 703,
#       "ALL_1": 542,
#       "ALL_2": 1,
#       "ALL_3": 1246
#     },
#     {
#       "SL. NO.": 3.0,
#       "DISTRICT": "DELHI CANTT",
#       "INSTITUTIONAL": 51.0,
#       "INSTITUTIONAL_1": 23.0,
#       "INSTITUTIONAL_2": 0.0,
#       "INSTITUTIONAL_3": 74,
#       "DOMICILIARY": 0.0,
#       "DOMICILIARY_1": 0.0,
#       "DOMICILIARY_2": 0.0,
#       "DOMICILIARY_3": 0,
#       "ALL": 51,
#       "ALL_1": 23,
#       "ALL_2": 0,
#       "ALL_3": 74
#     },
#     {
#       "SL. NO.": null,
#       "DISTRICT": "ALL",
#       "INSTITUTIONAL": 2995,
#       "INSTITUTIONAL_1": 2189,
#       "INSTITUTIONAL_2": 7,
#       "INSTITUTIONAL_3": 5191,
#       "DOMICILIARY": 14,
#       "DOMICILIARY_1": 20,
#       "DOMICILIARY_2": 0,
#       "DOMICILIARY_3": 34,
#       "ALL": 3009,
#       "ALL_1": 2209,
#       "ALL_2": 7,
#       "ALL_3": 5225
#     }
#   ],
#   "row_count": 4,
#   "raw_header_rows": [
#     [
#       "SL. NO.",
#       "DISTRICT",
#       "INSTITUTIONAL",
#       "INSTITUTIONAL",
#       "INSTITUTIONAL",
#       "INSTITUTIONAL",
#       "DOMICILIARY",
#       "DOMICILIARY",
#       "DOMICILIARY",
#       "DOMICILIARY",
#       "ALL",
#       "ALL",
#       "ALL",
#       "ALL"
#     ],
#     [
#       "SL. NO.",
#       "DISTRICT",
#       "MALE",
#       "FEMALE",
#       "OTHER",
#       "TOTAL",
#       "MALE",
#       "FEMALE",
#       "OTHER",
#       "TOTAL",
#       "MALE",
#       "FEMALE",
#       "OTHER",
#       "TOTAL"
#     ]
#   ],
#   "raw_col_num_rows": [],
#   "raw_notes": [],
#   "source_file": "Infant_Mother_Death_D12-D18.xlsx"
# }

# %%
categories = extractor.extract_category_metadata(
    title=tables[0]["table_id"],
    description=tables[0]["title"],
    raw_header_rows=tables[0]["raw_header_rows"],
    columns=tables[0]["columns"],
    sample_rows=tables[0]["rows"],
    raw_notes=tables[0]["raw_notes"],
)
print("Categories (empty because SKIP_LLM=True):", categories)
# Out:
# Categories (empty because SKIP_LLM=True): []

# %% [markdown]
# ## Stage 2 — KYDS (Know Your Dataset) form
#
# Mirrors `POST /api/kyds`: a free-form `responses` object plus a `user` block, persisted via
# `catalogue.save_kyds_entry`. This is independent of the extraction pipeline — it's a
# dataset-intake questionnaire captured alongside the upload.

# %%
# kyds_user = {"email": "aparajita@peopleplus.ai", "name": "Aparajita", "dept": "DES"}
# kyds_responses = {
#     "dataset_purpose": "Track live births and deaths by district for health planning",
#     "collection_method": "Administrative registration records",
#     "update_frequency": "Annual",
#     "known_limitations": "Provisional figures pending revision",
#     "sensitive_data": False,
# }

# print("KYDS submission payload:")
# print(json.dumps({"user": kyds_user, "responses": kyds_responses}, indent=2))

kyds_user = {
    "email": "aparajita@peopleplus.ai",
    "name": "Aparajita",
    "dept": "DES",
}

kyds_responses = {
    # 1. Modality
    "modality": ["Structured data"],
    "other_modality_describe": "",
    "specific_formats": "Excel (.xlsx)",

    # 2. Sensitivity and classification
    "dpdp_tiers": [],
    "special_category_subtypes": [],
    "degree_per_tier": "",

    "org_classification": ["Internal"],
    "national_classification": [],

    # 3. Access level
    "access_level": ["Open"],
    "more_open_subset": "",
    "restricted_sharing_partner": "",
    "embargoed_release": "",

    # 4. Granularity
    "granularity": ["District"],
    "restricted_to_sub_population": "No",
    "linked_persistent_id": "No",
    "longitudinal": "No",

    # 5. Update frequency and retention
    "update_frequency": ["Annual"],
    "retention": [],
    "retention_citation": "",

    # 6. Storage
    "storage": ["Online"],

    # 7. Notes and lawful basis
    "restricted_lawful_basis": "",
    "special_category_basis": "",
    "dpia": "No",
    "notes": "",

    # # Existing fields
    # "dataset_purpose": "Track live births and deaths by district for health planning",
    # "collection_method": "Administrative registration records",
    # "known_limitations": "Provisional figures pending revision",
    "sensitive_data": False,
}

print("KYDS submission payload:")
print(json.dumps({
    "user": kyds_user,
    "responses": kyds_responses
}, indent=2))
# Out:
# KYDS submission payload:
# {
#   "user": {
#     "email": "aparajita@peopleplus.ai",
#     "name": "Aparajita",
#     "dept": "DES"
#   },
#   "responses": {
#     "modality": [
#       "Structured data"
#     ],
#     "other_modality_describe": "",
#     "specific_formats": "Excel (.xlsx)",
#     "dpdp_tiers": [],
#     "special_category_subtypes": [],
#     "degree_per_tier": "",
#     "org_classification": [
#       "Internal"
#     ],
#     "national_classification": [],
#     "access_level": [
#       "Open"
#     ],
#     "more_open_subset": "",
#     "restricted_sharing_partner": "",
#     "embargoed_release": "",
#     "granularity": [
#       "District"
#     ],
#     "restricted_to_sub_population": "No",
#     "linked_persistent_id": "No",
#     "longitudinal": "No",
#     "update_frequency": [
#       "Annual"
#     ],
#     "retention": [],
#     "retention_citation": "",
#     "storage": [
#       "Online"
#     ],
#     "restricted_lawful_basis": "",
#     "special_category_basis": "",
#     "dpia": "No",
#     "notes": "",
#     "sensitive_data": false
#   }
# }

# %%
kyds_entry_id = None
if RUN_DB_PUSH:
    conn = cat.get_connection()
    cat.init_schema(conn)
    kyds_entry_id = cat.save_kyds_entry(conn, kyds_responses, kyds_user)
    conn.close()
    print(f"Saved KYDS entry, id={kyds_entry_id}")
else:
    print("RUN_DB_PUSH=False — skipping actual DB write. This is the row that *would* be inserted "
          "into kyds_entries:")
    print(json.dumps({"user_email": kyds_user["email"], "user_name": kyds_user["name"],
                       "user_dept": kyds_user["dept"], "responses": kyds_responses}, indent=2))
# Out:
# Saved KYDS entry, id=1

# %% [markdown]
# ## Stage 2.5 — Reconcile Table ID / Title mismatches
#
# Before grouping, cross-check each table's `table_id` / `title` with both validators
# (`validate_table_fields_code`, `validate_table_fields_llm`). When the two disagree on
# whether the fields are valid, the extraction is untrustworthy for that table -- ask the
# user to enter the correct `table_id` and `title` by hand so the error doesn't propagate
# into Stage 3's title-based grouping.

# %%
from validation import validate_table_fields_code, validate_table_fields_llm

print("Reconciling Table ID / Title mismatches before grouping\n")

# First pass: validate every table and collect ALL mismatches before
# touching stdin -- doing the input() prompt inline in the same loop
# meant a single interactive failure (e.g. no stdin available) aborted
# the whole loop and silently skipped every record after it.
#
# A "mismatch" is either validator disagreeing on validity (True vs False),
# OR both flagging the record invalid but for different reasons -- the two
# validators don't agree on WHAT is wrong, so the extraction is still not
# trustworthy and needs a human to resolve it.
mismatched = []
for t in tables:
    code_result = validate_table_fields_code(t["table_id"], t["title"])
    try:
        llm_result = validate_table_fields_llm(t["table_id"], t["title"])
    except Exception as e:
        llm_result = {"valid": None, "issues": [f"LLM validation skipped ({e})"]}

    both_invalid_different_reasons = (
        code_result["valid"] is False
        and llm_result["valid"] is False
        and set(code_result["issues"]) != set(llm_result["issues"])
    )
    if code_result["valid"] != llm_result["valid"] or both_invalid_different_reasons:
        mismatched.append((t, code_result, llm_result))

print(f"Found {len(mismatched)} mismatched record(s) out of {len(tables)} table(s)\n")

# Second pass: resolve each mismatch. A stdin failure on one record just
# keeps its existing values instead of aborting the remaining records.
for t, code_result, llm_result in mismatched:
    print(f"Mismatch on table id={t['id']}")
    print(f"  code-based validation  : valid={code_result['valid']} issues={code_result['issues']}")
    print(f"  prompt-based validation: valid={llm_result['valid']} issues={llm_result['issues']}")
    print(f"  current table_id : {t['table_id']}")
    print(f"  current title    : {t['title']}")

    try:
        new_table_id = input("  Enter correct Table ID: ").strip()
        new_title = input("  Enter correct Table Title: ").strip()
    except EOFError:
        print("  No interactive input available -- keeping existing values.\n")
        continue

    if new_table_id:
        t["table_id"] = new_table_id
    if new_title:
        t["title"] = new_title
    print()

print("Reconciliation complete. Proceeding to grouping.\n")
# Out:
# Reconciling Table ID / Title mismatches before grouping
#
# Found 1 mismatched record(s) out of 9 table(s)
#
# Mismatch on table id=DDI_DEL_DES_VS_D14_2024_V1
#   code-based validation  : valid=True issues=[]
#   prompt-based validation: valid=False issues=['The Table ID and Table Title look swapped']
#   current table_id : TABLE :D-14
#   current title    : INFANTS DEATHS BY AGE AND SEX
#   Enter correct Table ID:  TABLE :D-14
#   Enter correct Table Title:  INFANTS DEATHS BY AGE AND SEX
# Reconciliation complete. Proceeding to grouping.

# %% [markdown]
# ## Stage 3 — Automatic Grouping
#
# Tables are grouped automatically by extracting common patterns from their IDs and descriptions.
# Tables with the same sheet + matching ID prefixes (ignoring URBAN/RURAL/version suffixes) are grouped together.
# This eliminates the need for an external metadata workbook's inventory sheet.

# %%
import re

def auto_group_tables(tables):
    """
    Group tables automatically by their title.

    Strips trailing URBAN/RURAL-style parenthetical qualifiers from the
    title to find a common base title. Tables from the same sheet with
    matching base titles are grouped.
    """
    groups_dict = {}

    for table in tables:
        table_id = table["id"]
        sheet = table["sheet"]
        title = table.get("title", "") or ""

        # Strip a trailing parenthetical qualifier, e.g.
        # "INFANT DEATHS BY ... (URBAN)" -> "INFANT DEATHS BY ..."
        base_title = re.sub(r"\s*\([^)]*\)\s*$", "", title).strip()
        base_title = re.sub(r"\s+", " ", base_title).upper()
        if not base_title:
            base_title = title.strip().upper()

        group_key = (sheet, base_title)

        if group_key not in groups_dict:
            groups_dict[group_key] = {
                "sheet": sheet,
                "base_id": base_title,
                "table_ids": [],
                "tables": [],
            }

        groups_dict[group_key]["table_ids"].append(table_id)
        groups_dict[group_key]["tables"].append(table)

    return list(groups_dict.values())

# Auto-group extracted tables
groups = auto_group_tables(tables)

print(f"Auto-grouped {len(tables)} tables into {len(groups)} group(s)\n")
for i, g in enumerate(groups):
    print(f"Group {i+1}: sheet={g['sheet']}, base_id={g['base_id']}")
    print(f"  Table IDs: {g['table_ids']}")
    print()
# Out:
# Auto-grouped 9 tables into 5 group(s)
#
# Group 1: sheet=D-12 & D-13, base_id=INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS
#   Table IDs: ['DDI_DEL_DES_VS_D12_URBAN_2024_V1', 'DDI_DEL_DES_VS_D12_RURAL_2024_V1']
#
# Group 2: sheet=D-14, base_id=INFANTS DEATHS BY AGE AND SEX
#   Table IDs: ['DDI_DEL_DES_VS_D14_2024_V1']
#
# Group 3: sheet=D-15, base_id=PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS
#   Table IDs: ['DDI_DEL_DES_VS_D15_URBAN_2024_V1', 'DDI_DEL_DES_VS_D15_RURAL_2024_V1']
#
# Group 4: sheet=D-16, base_id=PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS
#   Table IDs: ['DDI_DEL_DES_VS_D16_URBAN_2024_V1', 'DDI_DEL_DES_VS_D16_RURAL_2024_V1']
#
# Group 5: sheet=D-18, base_id=PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION
#   Table IDs: ['DDI_DEL_DES_VS_D18_URBAN_2024_V1', 'DDI_DEL_DES_VS_D18_RURAL_2024_V1']

# %% [markdown]
# ## Stage 4 — LLM Metadata Creation per Group
#
# Once tables are grouped, the LLM generates metadata for each group using:
#
# 1. **Excel-derived facts** — `metadata_llm.extract_excel_facts` extracts sheet names, table boundaries, headers, column names, sample rows, geography, and units from the workbook
# 2. **KYDS responses** — human-provided form data from Stage 2
#
# The LLM uses both to populate product, category, geography, frequency, title, description, etc. for the group.

# %%
def generate_metadata_per_group(groups, excel_bytes, filename, kyds_responses, skip_llm=False):
    """
    Generate LLM metadata for each group.
    
    Args:
        groups: list of group dicts (from auto_group_tables)
        excel_bytes: workbook bytes
        filename: workbook filename
        kyds_responses: KYDS form responses
        skip_llm: if True, use heuristic fallback
    
    Returns:
        dict mapping group_key -> llm_filled_metadata
    """
    excel_facts = extract_excel_facts(excel_bytes, filename)
    group_metadata = {}
    
    for group in groups:
        group_key = (group["sheet"], group["base_id"])
        
        if not skip_llm:
            llm_output = generate_metadata_with_llm(
                excel_facts,
                kyds=kyds_responses,
                api_key=os.getenv("OPENAI_API_KEY"),
            )
            llm_filled = parse_llm_metadata_output(llm_output)
        else:
            # Heuristic: derive from table descriptions
            descriptions = [t.get("description", "") for t in group["tables"]]
            desc_str = " ".join(descriptions)
            
            llm_filled = {
                "title": group["base_id"],
                "product": "Health Statistics",
                "category": "Health",
                "geography": ["District", "Urban", "Rural"] if "URBAN" in desc_str or "RURAL" in desc_str else ["District"],
                "frequency": "Annual",
                "time_period": None,
                "data_source": None,
                "description": " | ".join(descriptions[:2]),
                "last_updated": None,
                "future_release": None,
                "key_statistics": None,
                "remarks": None,
            }
        
        group_metadata[group_key] = llm_filled
    
    return group_metadata

# Generate metadata for each group
group_metadata = generate_metadata_per_group(groups, sample_bytes, sample_filename, kyds_responses, skip_llm=SKIP_LLM)

# %%
print("Generated metadata for each group:\\n")
for group in groups:
    group_key = (group["sheet"], group["base_id"])
    meta = group_metadata[group_key]
    print(f"Group: sheet={group['sheet']}, base_id={group['base_id']}")
    print(f"  Tables: {group['table_ids']}")
    print(f"  Metadata: product={meta.get('product')}, category={meta.get('category')}, geography={meta.get('geography')}, description={meta.get('description')}")
    print()
# Out:
# Generated metadata for each group:\n
# Group: sheet=D-12 & D-13, base_id=INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS
#   Tables: ['DDI_DEL_DES_VS_D12_URBAN_2024_V1', 'DDI_DEL_DES_VS_D12_RURAL_2024_V1']
#   Metadata: product=Infant Mother Death Statistics, category=Vital Statistics, geography=District, description=Dataset on infant and mother deaths across urban and rural districts, segmented by place of occurrence, age, sex, and related causes.
#
# Group: sheet=D-14, base_id=INFANTS DEATHS BY AGE AND SEX
#   Tables: ['DDI_DEL_DES_VS_D14_2024_V1']
#   Metadata: product=Infant and Mother Death Statistics Dataset, category=Health Statistics, geography=['District', 'Urban', 'Rural'], description=This dataset provides detailed statistics on infant and mother deaths, categorized by various factors such as place of occurrence, age, and occupation across urban and rural districts.
#
# Group: sheet=D-15, base_id=PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS
#   Tables: ['DDI_DEL_DES_VS_D15_URBAN_2024_V1', 'DDI_DEL_DES_VS_D15_RURAL_2024_V1']
#   Metadata: product=Infant and Mother Death Data, category=Health and Demographics, geography=District, description=This dataset contains statistics on infant deaths by place of occurrence and districts in both urban and rural settings, infant deaths by age and sex, pregnancy-related deaths by age group and cause of death, and pregnancy-related deaths by age and occupation. The data is presented in a structured format and covers districts.
#
# Group: sheet=D-16, base_id=PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS
#   Tables: ['DDI_DEL_DES_VS_D16_URBAN_2024_V1', 'DDI_DEL_DES_VS_D16_RURAL_2024_V1']
#   Metadata: product=Infant and Mother Mortality Statistics, category=None, geography=Urban and Rural Districts, description=This dataset provides statistics on infant deaths by place of occurrence and sex, and maternal deaths by age group, cause, and occupation across urban and rural districts.
#
# Group: sheet=D-18, base_id=PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION
#   Tables: ['DDI_DEL_DES_VS_D18_URBAN_2024_V1', 'DDI_DEL_DES_VS_D18_RURAL_2024_V1']
#   Metadata: product=Infant Mother Death Data, category=Health, geography=['District', 'Urban', 'Rural'], description=This dataset provides statistics on infant and maternal deaths categorized by place of occurrence, age, sex, and occupation, primarily separated into urban and rural districts.

# %%
for group in groups:
    group_key = (group["sheet"], group["base_id"])
    meta = group_metadata[group_key]
    group_tables = group["tables"]
    
    # Placeholder enrichment (real enrichment = extractor.enrich_for_catalogue, the next stage)
    placeholder_enriched = [
        {
            "short_description": t.get("description") or t.get("title", ""),
            "long_description": t.get("description") or t.get("title", ""),
            "units": "Count",
            "classifications": {},   # <-- column classification would populate this
            "age_column_keys": {},
        }
        for t in group_tables
    ]
    
    print(f"\\n{'='*60}")
    print(f"Pushing group: {meta.get('product')} > {meta.get('category')}")
    print(f"  Tables: {group['table_ids']}")
    print(f"  Metadata fields:")
    for field, value in meta.items():
        if value is not None:
            print(f"    {field:16}: {value}")
    
    if RUN_DB_PUSH:
        conn = cat.get_connection()
        cat.init_schema(conn)
        result = cat.push_to_catalogue(
            conn, group_tables, placeholder_enriched, "new", None,
            meta.get("title") or meta.get("product"), meta.get("description"),
            meta.get("product"), meta.get("category"), 
            str(meta.get("geography")) if meta.get("geography") else None,
            meta.get("frequency"), meta.get("time_period"), meta.get("data_source"),
            meta.get("last_updated"), meta.get("future_release"),
            meta.get("key_statistics"), meta.get("remarks"), None,
        )
        conn.close()
        print(f"\\n  Result: metadata_id={result.get('metadata_id')}, {result.get('tables_pushed')} tables pushed")
    else:
        print(f"\\n  RUN_DB_PUSH=False — would insert:")
        print(json.dumps({
            "title": meta.get("title") or meta.get("product"),
            "product": meta.get("product"),
            "category": meta.get("category"),
            "table_ids": group["table_ids"],
        }, indent=4))

print(f"\\n{'='*60}")
print(f"\\nPipeline complete: {len(groups)} group(s), {len(tables)} table(s) total")
# Out:
# \n============================================================
# Pushing group: Infant Mother Death Statistics > Vital Statistics
#   Tables: ['DDI_DEL_DES_VS_D12_URBAN_2024_V1', 'DDI_DEL_DES_VS_D12_RURAL_2024_V1']
#   Metadata fields:
#     title           : Infant and Mother Death Data by Districts
#     product         : Infant Mother Death Statistics
#     category        : Vital Statistics
#     geography       : District
#     frequency       : Annual
#     time_period     : null
#     data_source     : Excel (.xlsx)
#     description     : Dataset on infant and mother deaths across urban and rural districts, segmented by place of occurrence, age, sex, and related causes.
#     last_updated    : null
#     future_release  : null
#     key_statistics  : {'Total Urban Infant Deaths': 5225, 'Total Rural Infant Deaths': 1641, 'Total Urban Mother Deaths (Table D-15)': 58, 'Total Rural Mother Deaths (Table D-15)': 55, 'Total Pregnancy-related Deaths (Urban)': 79, 'Total Pregnancy-related Deaths (Rural)': 57}
#     remarks         : The dataset provides separate statistics for urban and rural areas. The data presentation focuses on age, sex, institution of death occurrence, and occupation. Annual updates are implied, but specific last update and future release dates are not provided.

# %% [markdown]
# ## Stage 5 — Metadata Filling and Push to Catalogue
#
# Now we push each group's metadata to the catalogue via `push_to_catalogue`.
# This creates one `metadata_groups` row (group-level metadata) and one `datasets` row per table in the group.
#
# Per-table enrichment (classifications, units, age_column_keys) is normally populated by
# `extractor.enrich_for_catalogue` (column classification) — that's the next stage and is
# intentionally excluded here. We use placeholder enrichment to show the exact shape the push expects.

# %%
from metadata_llm import extract_excel_facts, generate_metadata_with_llm

excel_facts = extract_excel_facts(sample_bytes, sample_filename)

print(f"Sheets processed: {len(excel_facts['sheets'])}")
for sheet in excel_facts["sheets"]:
    print(f"\nSheet: {sheet['sheet_name']}  ({len(sheet['tables'])} table block(s))")
    for tbl in sheet["tables"]:
        print(f"  - boundaries={tbl['table_boundaries']}  identifiers={tbl['table_identifiers']}"
              f"  multi_row_header={tbl['multi_row_header']}  geography={tbl['geography']}"
              f"  units={tbl['units']}  periods={tbl['periods']}")

# %%
# Full excel_facts structure, for inspection
print(json.dumps(excel_facts, indent=2, default=str))
# Out:
# {
#   "filename": "Infant_Mother_Death_D12-D18.xlsx",
#   "sheets": [
#     {
#       "sheet_name": "D-12 & D-13",
#       "tables": [
#         {
#           "sheet_name": "D-12 & D-13",
#           "title_context": "TABLE: D-12 & D-13",
#           "description": "INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (URBAN)",
#           "table_name": "D-12 & D-13 / TABLE: D-12 & D-13",
#           "table_boundaries": {
#             "start_row": 0,
#             "end_row": 7,
#             "n_rows": 8,
#             "n_cols": 14
#           },
#           "table_identifiers": [
#             "D-12",
#             "D-13"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "DISTRICT",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "ALL",
#               "ALL",
#               "ALL",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "DISTRICT",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "DISTRICT",
#             "INSTITUTIONAL / MALE",
#             "INSTITUTIONAL / FEMALE",
#             "INSTITUTIONAL / OTHER",
#             "INSTITUTIONAL / TOTAL",
#             "DOMICILIARY / MALE",
#             "DOMICILIARY / FEMALE",
#             "DOMICILIARY / OTHER",
#             "DOMICILIARY / TOTAL",
#             "ALL / MALE",
#             "ALL / FEMALE",
#             "ALL / OTHER",
#             "ALL / TOTAL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "DISTRICT": "MCD",
#               "INSTITUTIONAL / MALE": 2241.0,
#               "INSTITUTIONAL / FEMALE": 1624.0,
#               "INSTITUTIONAL / OTHER": 6.0,
#               "INSTITUTIONAL / TOTAL": 3871,
#               "DOMICILIARY / MALE": 14.0,
#               "DOMICILIARY / FEMALE": 20.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 34,
#               "ALL / MALE": 2255,
#               "ALL / FEMALE": 1644,
#               "ALL / OTHER": 6,
#               "ALL / TOTAL": 3905
#             },
#             {
#               "SL. NO.": 2.0,
#               "DISTRICT": "NDMC   ",
#               "INSTITUTIONAL / MALE": 703.0,
#               "INSTITUTIONAL / FEMALE": 542.0,
#               "INSTITUTIONAL / OTHER": 1.0,
#               "INSTITUTIONAL / TOTAL": 1246,
#               "DOMICILIARY / MALE": 0.0,
#               "DOMICILIARY / FEMALE": 0.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 0,
#               "ALL / MALE": 703,
#               "ALL / FEMALE": 542,
#               "ALL / OTHER": 1,
#               "ALL / TOTAL": 1246
#             },
#             {
#               "SL. NO.": 3.0,
#               "DISTRICT": "DELHI CANTT",
#               "INSTITUTIONAL / MALE": 51.0,
#               "INSTITUTIONAL / FEMALE": 23.0,
#               "INSTITUTIONAL / OTHER": 0.0,
#               "INSTITUTIONAL / TOTAL": 74,
#               "DOMICILIARY / MALE": 0.0,
#               "DOMICILIARY / FEMALE": 0.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 0,
#               "ALL / MALE": 51,
#               "ALL / FEMALE": 23,
#               "ALL / OTHER": 0,
#               "ALL / TOTAL": 74
#             },
#             {
#               "SL. NO.": null,
#               "DISTRICT": "ALL",
#               "INSTITUTIONAL / MALE": 2995,
#               "INSTITUTIONAL / FEMALE": 2189,
#               "INSTITUTIONAL / OTHER": 7,
#               "INSTITUTIONAL / TOTAL": 5191,
#               "DOMICILIARY / MALE": 14,
#               "DOMICILIARY / FEMALE": 20,
#               "DOMICILIARY / OTHER": 0,
#               "DOMICILIARY / TOTAL": 34,
#               "ALL / MALE": 3009,
#               "ALL / FEMALE": 2209,
#               "ALL / OTHER": 7,
#               "ALL / TOTAL": 5225
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "DISTRICT",
#             "URBAN"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "DISTRICT",
#               "values": [
#                 "ALL",
#                 "DELHI CANTT",
#                 "MCD",
#                 "NDMC"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "ALL",
#                 "DISTRICT",
#                 "DOMICILIARY",
#                 "INSTITUTIONAL"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "DISTRICT",
#                 "FEMALE",
#                 "MALE",
#                 "OTHER",
#                 "TOTAL"
#               ]
#             }
#           ],
#           "block_index": 0
#         },
#         {
#           "sheet_name": "D-12 & D-13",
#           "title_context": "TABLE: D-12 & D-13",
#           "description": "INFANT DEATHS BY PLACE OF OCCURRENCE, DISTRICTS (RURAL)",
#           "table_name": "D-12 & D-13 / TABLE: D-12 & D-13",
#           "table_boundaries": {
#             "start_row": 10,
#             "end_row": 17,
#             "n_rows": 8,
#             "n_cols": 14
#           },
#           "table_identifiers": [
#             "D-12",
#             "D-13"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "DISTRICT",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "INSTITUTIONAL",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "DOMICILIARY",
#               "ALL",
#               "ALL",
#               "ALL",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "DISTRICT",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "TOTAL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "DISTRICT",
#             "INSTITUTIONAL / MALE",
#             "INSTITUTIONAL / FEMALE",
#             "INSTITUTIONAL / OTHER",
#             "INSTITUTIONAL / TOTAL",
#             "DOMICILIARY / MALE",
#             "DOMICILIARY / FEMALE",
#             "DOMICILIARY / OTHER",
#             "DOMICILIARY / TOTAL",
#             "ALL / MALE",
#             "ALL / FEMALE",
#             "ALL / OTHER",
#             "ALL / TOTAL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "DISTRICT": "MCD",
#               "INSTITUTIONAL / MALE": 296.0,
#               "INSTITUTIONAL / FEMALE": 185.0,
#               "INSTITUTIONAL / OTHER": 0.0,
#               "INSTITUTIONAL / TOTAL": 481,
#               "DOMICILIARY / MALE": 1.0,
#               "DOMICILIARY / FEMALE": 1.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 2,
#               "ALL / MALE": 297,
#               "ALL / FEMALE": 186,
#               "ALL / OTHER": 0,
#               "ALL / TOTAL": 483
#             },
#             {
#               "SL. NO.": 2.0,
#               "DISTRICT": "NDMC   ",
#               "INSTITUTIONAL / MALE": 726.0,
#               "INSTITUTIONAL / FEMALE": 430.0,
#               "INSTITUTIONAL / OTHER": 2.0,
#               "INSTITUTIONAL / TOTAL": 1158,
#               "DOMICILIARY / MALE": 0.0,
#               "DOMICILIARY / FEMALE": 0.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 0,
#               "ALL / MALE": 726,
#               "ALL / FEMALE": 430,
#               "ALL / OTHER": 2,
#               "ALL / TOTAL": 1158
#             },
#             {
#               "SL. NO.": 3.0,
#               "DISTRICT": "DELHI CANTT",
#               "INSTITUTIONAL / MALE": 0.0,
#               "INSTITUTIONAL / FEMALE": 0.0,
#               "INSTITUTIONAL / OTHER": 0.0,
#               "INSTITUTIONAL / TOTAL": 0,
#               "DOMICILIARY / MALE": 0.0,
#               "DOMICILIARY / FEMALE": 0.0,
#               "DOMICILIARY / OTHER": 0.0,
#               "DOMICILIARY / TOTAL": 0,
#               "ALL / MALE": 0,
#               "ALL / FEMALE": 0,
#               "ALL / OTHER": 0,
#               "ALL / TOTAL": 0
#             },
#             {
#               "SL. NO.": null,
#               "DISTRICT": "ALL",
#               "INSTITUTIONAL / MALE": 1022,
#               "INSTITUTIONAL / FEMALE": 615,
#               "INSTITUTIONAL / OTHER": 2,
#               "INSTITUTIONAL / TOTAL": 1639,
#               "DOMICILIARY / MALE": 1,
#               "DOMICILIARY / FEMALE": 1,
#               "DOMICILIARY / OTHER": 0,
#               "DOMICILIARY / TOTAL": 2,
#               "ALL / MALE": 1023,
#               "ALL / FEMALE": 616,
#               "ALL / OTHER": 2,
#               "ALL / TOTAL": 1641
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "DISTRICT",
#             "RURAL"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "DISTRICT",
#               "values": [
#                 "ALL",
#                 "DELHI CANTT",
#                 "MCD",
#                 "NDMC"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "ALL",
#                 "DISTRICT",
#                 "DOMICILIARY",
#                 "INSTITUTIONAL"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "DISTRICT",
#                 "FEMALE",
#                 "MALE",
#                 "OTHER",
#                 "TOTAL"
#               ]
#             }
#           ],
#           "block_index": 1
#         }
#       ]
#     },
#     {
#       "sheet_name": "D-14",
#       "tables": [
#         {
#           "sheet_name": "D-14",
#           "title_context": "TABLE :D-14",
#           "description": "INFANTS DEATHS BY AGE AND SEX",
#           "table_name": "D-14 / TABLE :D-14",
#           "table_boundaries": {
#             "start_row": 0,
#             "end_row": 7,
#             "n_rows": 8,
#             "n_cols": 14
#           },
#           "table_identifiers": [
#             "D-14"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "AGE",
#               "URBAN",
#               "URBAN",
#               "URBAN",
#               "URBAN",
#               "RURAL",
#               "RURAL",
#               "RURAL",
#               "RURAL",
#               "ALL",
#               "ALL",
#               "ALL",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "AGE",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "ALL",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "ALL ",
#               "MALE",
#               "FEMALE",
#               "OTHER",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "AGE",
#             "URBAN / MALE",
#             "URBAN / FEMALE",
#             "URBAN / OTHER",
#             "URBAN / ALL",
#             "RURAL / MALE",
#             "RURAL / FEMALE",
#             "RURAL / OTHER",
#             "RURAL / ALL",
#             "ALL / MALE",
#             "ALL / FEMALE",
#             "ALL / OTHER",
#             "ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "AGE": "< 7 DAYS",
#               "URBAN / MALE": 1507.0,
#               "URBAN / FEMALE": 1056.0,
#               "URBAN / OTHER": 7.0,
#               "URBAN / ALL": 2570,
#               "RURAL / MALE": 394.0,
#               "RURAL / FEMALE": 238.0,
#               "RURAL / OTHER": 1.0,
#               "RURAL / ALL": 633,
#               "ALL / MALE": 1901.0,
#               "ALL / FEMALE": 1294.0,
#               "ALL / OTHER": 8.0,
#               "ALL": 3203
#             },
#             {
#               "SL. NO.": 2.0,
#               "AGE": "7-28 DAYS",
#               "URBAN / MALE": 521.0,
#               "URBAN / FEMALE": 377.0,
#               "URBAN / OTHER": 0.0,
#               "URBAN / ALL": 898,
#               "RURAL / MALE": 145.0,
#               "RURAL / FEMALE": 83.0,
#               "RURAL / OTHER": 0.0,
#               "RURAL / ALL": 228,
#               "ALL / MALE": 666.0,
#               "ALL / FEMALE": 460.0,
#               "ALL / OTHER": 0.0,
#               "ALL": 1126
#             },
#             {
#               "SL. NO.": 3.0,
#               "AGE": "28 DAYS TO 1 YEAR",
#               "URBAN / MALE": 981.0,
#               "URBAN / FEMALE": 776.0,
#               "URBAN / OTHER": 0.0,
#               "URBAN / ALL": 1757,
#               "RURAL / MALE": 484.0,
#               "RURAL / FEMALE": 295.0,
#               "RURAL / OTHER": 1.0,
#               "RURAL / ALL": 780,
#               "ALL / MALE": 1465.0,
#               "ALL / FEMALE": 1071.0,
#               "ALL / OTHER": 1.0,
#               "ALL": 2537
#             },
#             {
#               "SL. NO.": null,
#               "AGE": "ALL",
#               "URBAN / MALE": 3009,
#               "URBAN / FEMALE": 2209,
#               "URBAN / OTHER": 7,
#               "URBAN / ALL": 5225,
#               "RURAL / MALE": 1023,
#               "RURAL / FEMALE": 616,
#               "RURAL / OTHER": 2,
#               "RURAL / ALL": 1641,
#               "ALL / MALE": 4032,
#               "ALL / FEMALE": 2825,
#               "ALL / OTHER": 9,
#               "ALL": 6866
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [
#               "1901"
#             ],
#             "year_ranges": []
#           },
#           "geography": [
#             "RURAL",
#             "URBAN"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "AGE",
#               "values": [
#                 "28 DAYS TO 1 YEAR",
#                 "7-28 DAYS",
#                 "< 7 DAYS",
#                 "ALL"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "ALL",
#                 "RURAL",
#                 "URBAN"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "ALL",
#                 "FEMALE",
#                 "MALE",
#                 "OTHER"
#               ]
#             }
#           ],
#           "block_index": 0
#         }
#       ]
#     },
#     {
#       "sheet_name": "D-15",
#       "tables": [
#         {
#           "sheet_name": "D-15",
#           "title_context": "TABLE : D-15",
#           "description": "PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (URBAN)",
#           "table_name": "D-15 / TABLE : D-15",
#           "table_boundaries": {
#             "start_row": 0,
#             "end_row": 7,
#             "n_rows": 8,
#             "n_cols": 12
#           },
#           "table_identifiers": [
#             "D-15"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "< 15 yr",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "CAUSE",
#             "DESCRIPTION",
#             "AGE OF MOTHER / < 15 yr",
#             "AGE OF MOTHER / 15-19",
#             "AGE OF MOTHER / 20-24",
#             "AGE OF MOTHER / 25-29",
#             "AGE OF MOTHER / 30-34",
#             "AGE OF MOTHER / 35-39",
#             "AGE OF MOTHER / 40-44",
#             "AGE OF MOTHER / 45 AND ABOVE",
#             "ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "CAUSE": "O00-O08",
#               "DESCRIPTION": "PREGNANCY, WITH ABORTIVE OUTCOME",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 2.0,
#               "AGE OF MOTHER / 25-29": 2.0,
#               "AGE OF MOTHER / 30-34": 1.0,
#               "AGE OF MOTHER / 35-39": 1.0,
#               "AGE OF MOTHER / 40-44": 1.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 7
#             },
#             {
#               "SL. NO.": 2.0,
#               "CAUSE": "O10-O92",
#               "DESCRIPTION": "OTHER DIRECT OBSTRIC DEATHS",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 5.0,
#               "AGE OF MOTHER / 25-29": 11.0,
#               "AGE OF MOTHER / 30-34": 16.0,
#               "AGE OF MOTHER / 35-39": 4.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 1.0,
#               "ALL": 37
#             },
#             {
#               "SL. NO.": 3.0,
#               "CAUSE": "O95-O99",
#               "DESCRIPTION": "OTHER OBSTRIC CONDITIONS N.E.C.",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 1.0,
#               "AGE OF MOTHER / 25-29": 5.0,
#               "AGE OF MOTHER / 30-34": 4.0,
#               "AGE OF MOTHER / 35-39": 4.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 14
#             },
#             {
#               "SL. NO.": null,
#               "CAUSE": null,
#               "DESCRIPTION": "ALL",
#               "AGE OF MOTHER / < 15 yr": 0,
#               "AGE OF MOTHER / 15-19": 0,
#               "AGE OF MOTHER / 20-24": 8,
#               "AGE OF MOTHER / 25-29": 18,
#               "AGE OF MOTHER / 30-34": 21,
#               "AGE OF MOTHER / 35-39": 9,
#               "AGE OF MOTHER / 40-44": 1,
#               "AGE OF MOTHER / 45 AND ABOVE": 1,
#               "ALL": 58
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "URBAN"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "CAUSE",
#               "values": [
#                 "O00-O08",
#                 "O10-O92",
#                 "O95-O99"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE OF MOTHER",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "< 15 yr",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             }
#           ],
#           "block_index": 0
#         },
#         {
#           "sheet_name": "D-15",
#           "title_context": "TABLE : D-15",
#           "description": "PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED DEATHS (RURAL)",
#           "table_name": "D-15 / TABLE : D-15",
#           "table_boundaries": {
#             "start_row": 10,
#             "end_row": 17,
#             "n_rows": 8,
#             "n_cols": 12
#           },
#           "table_identifiers": [
#             "D-15"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "< 15 yr",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "CAUSE",
#             "DESCRIPTION",
#             "AGE OF MOTHER / < 15 yr",
#             "AGE OF MOTHER / 15-19",
#             "AGE OF MOTHER / 20-24",
#             "AGE OF MOTHER / 25-29",
#             "AGE OF MOTHER / 30-34",
#             "AGE OF MOTHER / 35-39",
#             "AGE OF MOTHER / 40-44",
#             "AGE OF MOTHER / 45 AND ABOVE",
#             "ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "CAUSE": "O00-O08",
#               "DESCRIPTION": "PREGNANCY, WITH ABORTIVE OUTCOME",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 0.0,
#               "AGE OF MOTHER / 25-29": 1.0,
#               "AGE OF MOTHER / 30-34": 0.0,
#               "AGE OF MOTHER / 35-39": 0.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 1
#             },
#             {
#               "SL. NO.": 2.0,
#               "CAUSE": "O10-O92",
#               "DESCRIPTION": "OTHER DIRECT OBSTRIC DEATHS",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 1.0,
#               "AGE OF MOTHER / 20-24": 4.0,
#               "AGE OF MOTHER / 25-29": 8.0,
#               "AGE OF MOTHER / 30-34": 6.0,
#               "AGE OF MOTHER / 35-39": 2.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 1.0,
#               "ALL": 22
#             },
#             {
#               "SL. NO.": 3.0,
#               "CAUSE": "O95-O99",
#               "DESCRIPTION": "OTHER OBSTRIC CONDITIONS N.E.C.",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 11.0,
#               "AGE OF MOTHER / 25-29": 14.0,
#               "AGE OF MOTHER / 30-34": 6.0,
#               "AGE OF MOTHER / 35-39": 1.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 32
#             },
#             {
#               "SL. NO.": null,
#               "CAUSE": null,
#               "DESCRIPTION": "ALL",
#               "AGE OF MOTHER / < 15 yr": 0,
#               "AGE OF MOTHER / 15-19": 1,
#               "AGE OF MOTHER / 20-24": 15,
#               "AGE OF MOTHER / 25-29": 23,
#               "AGE OF MOTHER / 30-34": 12,
#               "AGE OF MOTHER / 35-39": 3,
#               "AGE OF MOTHER / 40-44": 0,
#               "AGE OF MOTHER / 45 AND ABOVE": 1,
#               "ALL": 55
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "RURAL"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "CAUSE",
#               "values": [
#                 "O00-O08",
#                 "O10-O92",
#                 "O95-O99"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE OF MOTHER",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "< 15 yr",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             }
#           ],
#           "block_index": 1
#         }
#       ]
#     },
#     {
#       "sheet_name": "D-16",
#       "tables": [
#         {
#           "sheet_name": "D-16",
#           "title_context": "TABLE : D-16",
#           "description": "PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (URBAN)",
#           "table_name": "D-16 / TABLE : D-16",
#           "table_boundaries": {
#             "start_row": 0,
#             "end_row": 7,
#             "n_rows": 8,
#             "n_cols": 12
#           },
#           "table_identifiers": [
#             "D-16"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "< 15 yr",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "CAUSE",
#             "DESCRIPTION",
#             "AGE OF MOTHER / < 15 yr",
#             "AGE OF MOTHER / 15-19",
#             "AGE OF MOTHER / 20-24",
#             "AGE OF MOTHER / 25-29",
#             "AGE OF MOTHER / 30-34",
#             "AGE OF MOTHER / 35-39",
#             "AGE OF MOTHER / 40-44",
#             "AGE OF MOTHER / 45 AND ABOVE",
#             "ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "CAUSE": "O00-O08",
#               "DESCRIPTION": "PREGNANCY, WITH ABORTIVE OUTCOME",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 1.0,
#               "AGE OF MOTHER / 20-24": 2.0,
#               "AGE OF MOTHER / 25-29": 3.0,
#               "AGE OF MOTHER / 30-34": 2.0,
#               "AGE OF MOTHER / 35-39": 3.0,
#               "AGE OF MOTHER / 40-44": 1.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 5.0,
#               "ALL": 17
#             },
#             {
#               "SL. NO.": 2.0,
#               "CAUSE": "O10-O92",
#               "DESCRIPTION": "OTHER DIRECT OBSTRIC DEATHS",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 6.0,
#               "AGE OF MOTHER / 25-29": 11.0,
#               "AGE OF MOTHER / 30-34": 16.0,
#               "AGE OF MOTHER / 35-39": 4.0,
#               "AGE OF MOTHER / 40-44": 1.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 2.0,
#               "ALL": 40
#             },
#             {
#               "SL. NO.": 3.0,
#               "CAUSE": "O95-O99",
#               "DESCRIPTION": "OTHER OBSTRIC CONDITIONS N.E.C.",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 1.0,
#               "AGE OF MOTHER / 25-29": 5.0,
#               "AGE OF MOTHER / 30-34": 4.0,
#               "AGE OF MOTHER / 35-39": 5.0,
#               "AGE OF MOTHER / 40-44": 1.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 6.0,
#               "ALL": 22
#             },
#             {
#               "SL. NO.": null,
#               "CAUSE": null,
#               "DESCRIPTION": "ALL",
#               "AGE OF MOTHER / < 15 yr": 0,
#               "AGE OF MOTHER / 15-19": 1,
#               "AGE OF MOTHER / 20-24": 9,
#               "AGE OF MOTHER / 25-29": 19,
#               "AGE OF MOTHER / 30-34": 22,
#               "AGE OF MOTHER / 35-39": 12,
#               "AGE OF MOTHER / 40-44": 3,
#               "AGE OF MOTHER / 45 AND ABOVE": 13,
#               "ALL": 79
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "URBAN"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "CAUSE",
#               "values": [
#                 "O00-O08",
#                 "O10-O92",
#                 "O95-O99"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE OF MOTHER",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "< 15 yr",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             }
#           ],
#           "block_index": 0
#         },
#         {
#           "sheet_name": "D-16",
#           "title_context": "TABLE : D-16",
#           "description": "PREGNANCY RELATED DEATHS BY AGE GROUP OF THE DECEASED (MOTHER) AND CAUSE OF DEATH FOR MEDICALLY CERTIFIED OR NOT DEATHS (RURAL)",
#           "table_name": "D-16 / TABLE : D-16",
#           "table_boundaries": {
#             "start_row": 10,
#             "end_row": 17,
#             "n_rows": 8,
#             "n_cols": 12
#           },
#           "table_identifiers": [
#             "D-16"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "AGE OF MOTHER",
#               "ALL"
#             ],
#             [
#               "SL. NO.",
#               "CAUSE",
#               "DESCRIPTION",
#               "< 15 yr",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "CAUSE",
#             "DESCRIPTION",
#             "AGE OF MOTHER / < 15 yr",
#             "AGE OF MOTHER / 15-19",
#             "AGE OF MOTHER / 20-24",
#             "AGE OF MOTHER / 25-29",
#             "AGE OF MOTHER / 30-34",
#             "AGE OF MOTHER / 35-39",
#             "AGE OF MOTHER / 40-44",
#             "AGE OF MOTHER / 45 AND ABOVE",
#             "ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "CAUSE": "O00-O08",
#               "DESCRIPTION": "PREGNANCY, WITH ABORTIVE OUTCOME",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 0.0,
#               "AGE OF MOTHER / 25-29": 2.0,
#               "AGE OF MOTHER / 30-34": 1.0,
#               "AGE OF MOTHER / 35-39": 0.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 3
#             },
#             {
#               "SL. NO.": 2.0,
#               "CAUSE": "O10-O92",
#               "DESCRIPTION": "OTHER DIRECT OBSTRIC DEATHS",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 1.0,
#               "AGE OF MOTHER / 20-24": 4.0,
#               "AGE OF MOTHER / 25-29": 8.0,
#               "AGE OF MOTHER / 30-34": 6.0,
#               "AGE OF MOTHER / 35-39": 2.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 1.0,
#               "ALL": 22
#             },
#             {
#               "SL. NO.": 3.0,
#               "CAUSE": "O95-O99",
#               "DESCRIPTION": "OTHER OBSTRIC CONDITIONS N.E.C.",
#               "AGE OF MOTHER / < 15 yr": 0.0,
#               "AGE OF MOTHER / 15-19": 0.0,
#               "AGE OF MOTHER / 20-24": 11.0,
#               "AGE OF MOTHER / 25-29": 14.0,
#               "AGE OF MOTHER / 30-34": 6.0,
#               "AGE OF MOTHER / 35-39": 1.0,
#               "AGE OF MOTHER / 40-44": 0.0,
#               "AGE OF MOTHER / 45 AND ABOVE": 0.0,
#               "ALL": 32
#             },
#             {
#               "SL. NO.": null,
#               "CAUSE": null,
#               "DESCRIPTION": "ALL",
#               "AGE OF MOTHER / < 15 yr": 0,
#               "AGE OF MOTHER / 15-19": 1,
#               "AGE OF MOTHER / 20-24": 15,
#               "AGE OF MOTHER / 25-29": 24,
#               "AGE OF MOTHER / 30-34": 13,
#               "AGE OF MOTHER / 35-39": 3,
#               "AGE OF MOTHER / 40-44": 0,
#               "AGE OF MOTHER / 45 AND ABOVE": 1,
#               "ALL": 57
#             }
#           ],
#           "row_count": 4,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "RURAL"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "row_column",
#               "dimension": "Row dimension",
#               "column_name": "CAUSE",
#               "values": [
#                 "O00-O08",
#                 "O10-O92",
#                 "O95-O99"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE OF MOTHER",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "< 15 yr",
#                 "ALL",
#                 "CAUSE",
#                 "DESCRIPTION"
#               ]
#             }
#           ],
#           "block_index": 1
#         }
#       ]
#     },
#     {
#       "sheet_name": "D-18",
#       "tables": [
#         {
#           "sheet_name": "D-18",
#           "title_context": "TABLE: D-18",
#           "description": "PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (URBAN)",
#           "table_name": "D-18 / TABLE: D-18",
#           "table_boundaries": {
#             "start_row": 0,
#             "end_row": 13,
#             "n_rows": 14,
#             "n_cols": 11
#           },
#           "table_identifiers": [
#             "D-18"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "OCCUPATION",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP"
#             ],
#             [
#               "SL. NO.",
#               "OCCUPATION",
#               "<15",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "OCCUPATION",
#             "AGE GROUP / <15",
#             "AGE GROUP / 15-19",
#             "AGE GROUP / 20-24",
#             "AGE GROUP / 25-29",
#             "AGE GROUP / 30-34",
#             "AGE GROUP / 35-39",
#             "AGE GROUP / 40-44",
#             "AGE GROUP / 45 AND ABOVE",
#             "AGE GROUP / ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "OCCUPATION": "PROFESSIONAL / TECHNICAL RELATED WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 2.0,
#               "AGE GROUP / 30-34": 1.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 3
#             },
#             {
#               "SL. NO.": 2.0,
#               "OCCUPATION": "ADMINISTRATIVE, EXECUTIVE AND MANAGERIAL WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 3.0,
#               "OCCUPATION": "CLERICAL WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 4.0,
#               "OCCUPATION": "SALE WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 5.0,
#               "OCCUPATION": "SERVICE WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 1.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 1.0,
#               "AGE GROUP / 35-39": 1.0,
#               "AGE GROUP / 40-44": 1.0,
#               "AGE GROUP / 45 AND ABOVE": 5.0,
#               "AGE GROUP / ALL": 9
#             }
#           ],
#           "row_count": 10,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "URBAN"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE GROUP",
#                 "OCCUPATION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "<15",
#                 "ALL",
#                 "OCCUPATION"
#               ]
#             }
#           ],
#           "block_index": 0
#         },
#         {
#           "sheet_name": "D-18",
#           "title_context": "TABLE: D-18",
#           "description": "PREGNANCY RELATED DEATHS BY AGE AND OCCUPATION (RURAL)",
#           "table_name": "D-18 / TABLE: D-18",
#           "table_boundaries": {
#             "start_row": 15,
#             "end_row": 28,
#             "n_rows": 14,
#             "n_cols": 11
#           },
#           "table_identifiers": [
#             "D-18"
#           ],
#           "raw_header_rows": [
#             [
#               "SL. NO.",
#               "OCCUPATION",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP",
#               "AGE GROUP"
#             ],
#             [
#               "SL. NO.",
#               "OCCUPATION",
#               "<15",
#               "15-19",
#               "20-24",
#               "25-29",
#               "30-34",
#               "35-39",
#               "40-44",
#               "45 AND ABOVE",
#               "ALL"
#             ]
#           ],
#           "column_names": [
#             "SL. NO.",
#             "OCCUPATION",
#             "AGE GROUP / <15",
#             "AGE GROUP / 15-19",
#             "AGE GROUP / 20-24",
#             "AGE GROUP / 25-29",
#             "AGE GROUP / 30-34",
#             "AGE GROUP / 35-39",
#             "AGE GROUP / 40-44",
#             "AGE GROUP / 45 AND ABOVE",
#             "AGE GROUP / ALL"
#           ],
#           "multi_row_header": true,
#           "n_header_rows": 2,
#           "sample_rows": [
#             {
#               "SL. NO.": 1.0,
#               "OCCUPATION": "PROFESSIONAL / TECHNICAL RELATED WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 2.0,
#               "OCCUPATION": "ADMINISTRATIVE, EXECUTIVE AND MANAGERIAL WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 3.0,
#               "OCCUPATION": "CLERICAL WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 4.0,
#               "OCCUPATION": "SALE WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             },
#             {
#               "SL. NO.": 5.0,
#               "OCCUPATION": "SERVICE WORKERS",
#               "AGE GROUP / <15": 0.0,
#               "AGE GROUP / 15-19": 0.0,
#               "AGE GROUP / 20-24": 0.0,
#               "AGE GROUP / 25-29": 0.0,
#               "AGE GROUP / 30-34": 0.0,
#               "AGE GROUP / 35-39": 0.0,
#               "AGE GROUP / 40-44": 0.0,
#               "AGE GROUP / 45 AND ABOVE": 0.0,
#               "AGE GROUP / ALL": 0
#             }
#           ],
#           "row_count": 10,
#           "periods": {
#             "years": [],
#             "year_ranges": []
#           },
#           "geography": [
#             "RURAL"
#           ],
#           "units": [],
#           "categorical_dimensions": [
#             {
#               "source": "column_header",
#               "dimension": "Column group",
#               "column_name": "(from header row 1)",
#               "values": [
#                 "AGE GROUP",
#                 "OCCUPATION"
#               ]
#             },
#             {
#               "source": "column_header",
#               "dimension": "Sub-column",
#               "column_name": "(from header row 2)",
#               "values": [
#                 "15-19",
#                 "20-24",
#                 "25-29",
#                 "30-34",
#                 "35-39",
#                 "40-44",
#                 "45 AND ABOVE",
#                 "<15",
#                 "ALL",
#                 "OCCUPATION"
#               ]
#             }
#           ],
#           "block_index": 1
#         }
#       ]
#     }
#   ]
# }

# %%
from metadata_llm import prepare_kyds_for_llm

if not SKIP_LLM:
    llm_metadata = generate_metadata_with_llm(
        excel_facts,
        kyds=kyds_responses,
        api_key=os.getenv("OPENAI_API_KEY"),
    )
    print(llm_metadata)
else:
    kyds_llm = prepare_kyds_for_llm(kyds_responses)
    print("SKIP_LLM=True — not calling OpenAI. Payload that would be sent (excel_facts + trimmed kyds):")
    print(json.dumps({
        "excel_facts": excel_facts,
        "dataset_context": kyds_llm,
    }, indent=2, default=str)[:2000], "...")
# Out:
# ```json
# {
#   "title": "Infant and Mother Deaths by Geography and Age",
#   "product": "Infant and Mother Death Statistics Dataset",
#   "category": null,
#   "geography": ["Urban", "Rural"],
#   "frequency": "Annual",
#   "time_period": null,
#   "data_source": null,
#   "description": "This dataset provides information on infant deaths categorized by place of occurrence, age, and sex, along with pregnancy-related deaths segmented by age and occupation of the deceased mother, across urban and rural districts.",
#   "last_updated": null,
#   "future_release": null,
#   "key_statistics": {
#     "total_infant_deaths": 6866,
#     "total_grave_urban_deaths": 5225,
#     "total_grave_rural_deaths": 1641,
#     "total_mother_deaths_urban": 58,
#     "total_mother_deaths_rural": 55
#   },
#   "remarks": "Data is presented at the district level and segregated into urban and rural areas. Infant deaths are further detailed by age and sex, while maternal deaths are categorized by age and occupation."
# }
# ```

# %% [markdown]
# ### Parse the LLM output and display the filled metadata fields
#
# `metadata_llm.parse_llm_metadata_output` strips any markdown fencing and parses the JSON returned
# above into a plain dict normalized to the catalogue's metadata fields (missing fields become `None`).

# %%
from metadata_llm import parse_llm_metadata_output

if not SKIP_LLM:
    llm_filled_metadata = parse_llm_metadata_output(llm_metadata)
else:
    print("SKIP_LLM=True — no LLM output to parse. Showing the Stage 3 catalogue_summary prefill instead:")
    llm_filled_metadata = {field: prefill_fields.get(field) for field in
                            ["title", "product", "category", "geography", "frequency", "time_period",
                             "data_source", "description", "last_updated", "future_release",
                             "key_statistics", "remarks"]}

print("LLM-filled metadata fields:")
for field, value in llm_filled_metadata.items():
    print(f"  {field:16}: {value}")
# Out:
# LLM-filled metadata fields:
#   title           : Still Births by Place of Occurrence in Districts
#   product         : Still Birth Data
#   category        : Health
#   geography       : ['District', 'Urban', 'Rural']
#   frequency       : Annual
#   time_period     : None
#   data_source     : None
#   description     : Dataset detailing stillbirth occurrences by gender and place of occurrence (institutional or domiciliary) in urban and rural districts.
#   last_updated    : None
#   future_release  : None
#   key_statistics  : {'total_urban_stillbirths': 1645, 'total_rural_stillbirths': 560}
#   remarks         : None

# %% [markdown]
# ---
# ## Summary — Simplified End-to-End Pipeline
#
# The notebook now demonstrates an **automatic, hardcode-free pipeline**:
#
# 1. ✅ **Extract tables** from workbook (Stage 1)
# 2. ✅ **KYDS form** submission (Stage 2)
# 3. ✅ **Auto-group tables** by ID patterns (URBAN/RURAL pairs, same sheet) (Stage 3)
# 4. ✅ **LLM metadata creation** per group from excel_facts + KYDS (Stage 4)
# 5. ✅ **Metadata filling & push** to catalogue (Stage 5)
#
# **Key differences from old flow:**
# - ❌ No hardcoded `build_sample_metadata_workbook()` function
# - ❌ No external metadata workbook required
# - ✅ Grouping is automatic, based on table ID patterns
# - ✅ Metadata is generated once per group (not per table)
#
# ⏸️ **Next stage** (not in this notebook): per-table **column classification**
# (`TableExtractor.enrich_for_catalogue`) to populate `units`, `classifications`, and `age_column_keys`.
